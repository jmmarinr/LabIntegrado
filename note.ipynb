# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Este es un título

# %%
np.log(10)
# Out:
# 2.302585092994046

# %%
x = np.linspace(0,10)
y = x**2
plt.plot(x,y)
plt.show()

# %%
data = {'X':x, 'Y':y}
df = pd.DataFrame(data)
df
# Out:
#             X           Y
# 0    0.000000    0.000000
# 1    0.204082    0.041649
# 2    0.408163    0.166597
# 3    0.612245    0.374844
# 4    0.816327    0.666389
# 5    1.020408    1.041233
# 6    1.224490    1.499375
# 7    1.428571    2.040816
# 8    1.632653    2.665556
# 9    1.836735    3.373594
# 10   2.040816    4.164931
# 11   2.244898    5.039567
# 12   2.448980    5.997501
# 13   2.653061    7.038734
# 14   2.857143    8.163265
# 15   3.061224    9.371095
# 16   3.265306   10.662224
# 17   3.469388   12.036651
# 18   3.673469   13.494377
# 19   3.877551   15.035402
# 20   4.081633   16.659725
# 21   4.285714   18.367347
# 22   4.489796   20.158267
# 23   4.693878   22.032486
# 24   4.897959   23.990004
# 25   5.102041   26.030820
# 26   5.306122   28.154935
# 27   5.510204   30.362349
# 28   5.714286   32.653061
# 29   5.918367   35.027072
# 30   6.122449   37.484382
# 31   6.326531   40.024990
# 32   6.530612   42.648896
# 33   6.734694   45.356102
# ...
